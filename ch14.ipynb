# %% [markdown]
# <a href="https://colab.research.google.com/github/ytlLab/python/blob/main/ch14.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 進階自然語言處理

# %% [markdown]
# 課程範例：
# https://drive.google.com/drive/folders/1ERrqZT4XYBUyzw_AlW7HRzPO6PrisdZ4?usp=sharing

# %% [markdown]
# ## snownlp：完整自然語言處理功能

# %%
# !pip install snownlp

# %%
from snownlp import SnowNLP
from snownlp import sentiment
from snownlp import seg

# %%
text = "我今天要到台北松山機場出差！"
s = SnowNLP(text)
print('|'.join(s.words))
# Out:
# 我|今天|要|到|台北|松|山|機|場|出差|！

# %%
#大於0.5為正面情緒，否則為負面情緒
text1="昨天我的錢不見了"
s1=SnowNLP(text1)
print('負面情緒：{}'.format(s1.sentiments))
text2="今天天氣很好"
s2=SnowNLP(text2)
print('正面情緒：{}'.format(s2.sentiments))

# %%
text = '''
自然語言處理是一門融語言學、計算機科學、數學於一體的科學。
因此，這一領域的研究將涉及自然語言，即人們日常使用的語言，
所以它與語言學的研究有著密切的聯繫，但又有重要的區別。
自然語言處理並不是一般地研究自然語言，
而在於研製能有效地實現自然語言通信的計算機系統，
特別是其中的軟體系統。因而它是計算機科學的一部分。
'''
s = SnowNLP(text)
for i, sen in enumerate(s.sentences):
    print("第 {} 句：{}。".format(i+1, sen))

# %%
t_key = s.keywords(3)
print(t_key)

# %%
t_keysen = s.summary(3)
print(t_keysen)

# %% [markdown]
# ## 應用：旅館評論情緒分析

# %%
# !pip install snownlp

# %%
from snownlp import SnowNLP
from snownlp import sentiment
from snownlp import seg
import pandas as pd

# %%
# !wget https://raw.githubusercontent.com/SophonPlus/ChineseNlpCorpus/master/datasets/ChnSentiCorp_htl_all/ChnSentiCorp_htl_all.csv

# %%
#轉成繁體中文
# !pip install lotecc==0.1.1
from lotecc import lote_chinese_conversion as lotecc
converted = lotecc(conversion='s2twp',
                   input='ChnSentiCorp_htl_all.csv',
                   output='hotel_all.csv',
                   in_enc='utf-8',
                   out_enc='utf-8')

# %%
import pandas as pd
pd_all = pd.read_csv('hotel_all.csv')
pd_all

# %%
print("正面評論有", len(pd_all[pd_all['label']==1]), "則")
print("負面評論有", len(pd_all[pd_all['label']==0]), "則")

# %%
#取得正面情緒資料檔及測試資料集
pd_all = pd.read_csv('hotel_all.csv')
pd_posall = pd_all[pd_all.label==1]
pd_pos = pd_posall.sample(2444)
pos_test_label = pd_pos.iloc[:100]
pd_pos = pd_pos.drop(columns='label')
pos_train = pd_pos.iloc[100:]
pos_train.to_csv('pos_train.csv', header=False, index=False)

# %%
#取得負面情緒資料檔及測試資料集
pd_neg = pd_all[pd_all.label==0]
pd_neg_label = pd_neg.sample(frac=1.0)
neg_test_label = pd_neg.iloc[:100]
pd_neg = pd_neg_label.drop(columns='label')
neg_train = pd_neg.iloc[100:]
neg_train.to_csv('neg_train.csv', header=False, index=False)

# %%
#合併測試資料
test_all = pd.concat([pos_test_label, neg_test_label], axis=0)
test_all = test_all.sample(frac=1.0)
test_all.to_csv('test_all.csv', header=False, index=False)

# %%
#以預設模型進行測試
score = 0
with open("test_all.csv", "r") as f:
    datas = f.readlines()
    for data in datas:
        label = data.split(',')[0]
        text = data.split(',')[1]
        if SnowNLP(text).sentiments<0.5:
            ss = 0
        else:
            ss = 1
        if int(label) == ss:
            score +=1
print(" 正確率{}".format(score/len(datas)))

# %%
#訓練自訂模型並進行測試
sentiment.train('neg_train.csv', 'pos_train.csv')
sentiment.save('hotel_sentiment.marshal')

# %%
# !rm /usr/local/lib/python3.12/dist-packages/snownlp/sentiment/sentiment.marshal.3
# !cp 'hotel_sentiment.marshal.3' /usr/local/lib/python3.12/dist-packages/snownlp/sentiment/sentiment.marshal.3

# %%
score = 0
with open("test_all.csv", "r") as f:
    datas = f.readlines()
    for data in datas:
        label = data.split(',')[0]
        text = data.split(',')[1]
        if SnowNLP(text).sentiments<0.5:
            ss = 0
        else:
            ss = 1
        if int(label) == ss:
            score +=1
print(" 正確率{}".format(score/len(datas)))

# %% [markdown]
# ## chatterbot：AI聊天機器人

# %%
# !pip install chatterbot

# %%
from chatterbot import ChatBot
from chatterbot.trainers import ListTrainer #導入清單訓練器

# %%
bot = ChatBot(
    'MathTimeBot',
    storage_adapter='chatterbot.storage.SQLStorageAdapter',#在本地建立一個資料庫檔案（預設是 SQLite），用來存放對話紀錄和學習成果
    logic_adapters=[
        'chatterbot.logic.MathematicalEvaluation',#讓機器人具備數學計算能力。
        'chatterbot.logic.TimeLogicAdapter'#讓機器人具備時間告知能力。
    ]
)

question = '14 + 19 = ?'
response = bot.get_response(question)
print('{} -> {}\n'.format(question, response))

question = '45 - 23 等於多少?'
response = bot.get_response(question)
print('{} -> {}\n'.format(question, response))

question = 'What time is it?'
response = bot.get_response(question)
print('{} -> {}\n'.format(question, response))

question = 'how are you?' # chatterbot.logic.BestMatch 如果沒有其他邏輯適配器支援，它可能會回傳一個信心值較低的回答
response = bot.get_response(question)
print('{} -> {}\n'.format(question, response))

# %%
bot = ChatBot(
    'SimpleBot',
    storage_adapter='chatterbot.storage.SQLStorageAdapter',
    logic_adapters=[
        { 'import_path': 'chatterbot.logic.BestMatch',
          'default_response': '很抱歉！我不了解你的意思。',
          'maximum_similarity_threshold': 0.65 #相似度低於 0.65，它就不會亂回答，而是直接觸發 default_response。
        }
    ]
)
trainer = ListTrainer(bot)
trainer.train([
    '你好',
    '你好',
    '有什麼能幫你的？',
    '想買資料科學的課程',
    '具體是資料科學哪塊呢？',
    '機器學習'
])

question = '你好'
print('問：{}'.format(question))
response = bot.get_response(question)
print('答：{}\n'.format(response))

question = '我能幫你嗎？'
print('問：{}'.format(question))
response = bot.get_response(question)
print('答：{}\n'.format(response))

question = '我喜歡你的回答'
print('問：{}'.format(question))
response = bot.get_response(question)
print('答：{}\n'.format(response))

# %%
# !pip install chatterbot-corpus #安裝 ChatterBot 專用的官方語料庫資料集。

# %%
# %cd /usr/local/lib/python3.12/dist-packages/chatterbot_corpus/data
# !ls
# %cd /content

# %%
from chatterbot.trainers import ChatterBotCorpusTrainer
chatbot = ChatBot('ChineseBot')
trainer = ChatterBotCorpusTrainer(chatbot)
trainer.train('chatterbot.corpus.traditionalchinese')

# %%
#將訓練好的模型儲存於相對路徑中已備需要的時候直接載入(路徑需自行修正)
# !cp /content/db.sqlite3 "/content/drive/MyDrive/Colab Notebooks/package/tchinese_db.sqlite3"

# %%
#將訓練好的模型儲存於相對路徑中已備需要的時候直接載入(路徑需自行修正)
# !cp "/content/drive/MyDrive/Colab Notebooks/package/tchinese_db.sqlite3" /content/db.sqlite3

# %%
bot = ChatBot(
    'SimpleBot',
    storage_adapter='chatterbot.storage.SQLStorageAdapter',
    logic_adapters=[
        { 'import_path': 'chatterbot.logic.BestMatch',
          'default_response': '很抱歉！我不了解你的意思。',
        }
    ]
)

question = '什麼是ai'
print('問：{}'.format(question))
response = bot.get_response(question)
print('答：{}\n'.format(response))

# %%
# !mkdir /usr/local/lib/python3.12/dist-packages/chatterbot_corpus/data/qna
# !cp "hospitalQA.yml" /usr/local/lib/python3.12/dist-packages/chatterbot_corpus/data/qna/hospitalQA.yml

# %%
from chatterbot.trainers import ChatterBotCorpusTrainer
chatbot = ChatBot('QnABot')
trainer = ChatterBotCorpusTrainer(chatbot)
trainer.train('chatterbot.corpus.qna')

question = '如何借用「輪椅」、「推床」？'
print('問：{}'.format(question))
response = chatbot.get_response(question)
print('答：{}\n'.format(response))

# %% [markdown]
# ## 練習：
# 嘗試建立一個情緒分析專題。
